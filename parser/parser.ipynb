# %%
# %load_ext autoreload
# %autoreload 2
from parser import *
import os
import json
import numpy as np

# %%
import wikipedia

# %%
wikipedia.page("Jfjdfsw").url
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\altrn\anaconda3\Lib\site-packages\wikipedia\wikipedia.py:272, in page(title, pageid, auto_suggest, redirect, preload)
#     271 try:
# --> 272   title = suggestion or results[0]
#     273 except IndexError:
#     274   # if there is no suggestion or search results, the page doesn't exist
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# PageError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 wikipedia.page("Jfjdfsw").url
#
# File c:\Users\altrn\anaconda3\Lib\site-packages\wikipedia\wikipedia.py:275, in page(title, pageid, auto_suggest, redirect, preload)
#     272       title = suggestion or results[0]
#     273     except IndexError:
# ...

# %%
with open("./../data.json", "r") as f:
    new_json = json.load(f)

# %%
person = new_json[np.random.randint(len(new_json))]
show_person("./../" + person["path"], person["caption"], person["bbox_info"])
