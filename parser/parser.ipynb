# %%
# %load_ext autoreload
# %autoreload 2
from parser import *
import os
import json
import numpy as np
# Out:
# Running cells with 'wikiLLM (Python 3.13.2)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n wikiLLM ipykernel --update-deps --force-reinstall'

# %%
with open("./../data.json", "r") as f:
    new_json = json.load(f)

# %%
person = new_json[np.random.randint(len(new_json))]
show_person("./../" + person["path"], person["caption"], person["bbox_info"])
