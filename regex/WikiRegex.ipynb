# %% [markdown]
# # Testing

# %% [markdown]
# ### Using regular expressions

# %%
import re

text = "Elizabeth (far left) on the balcony of Buckingham Palace with her family and Winston Churchill, 8 May 1945"
text += " and her 3046 soldiers born in 982"

# patterns
p1 = r"\d{4}"                       # 4 digit number
p2 = r"\b[12]\d{3}\b"               # 4 digit number beginning with a 1 or a 2
p3 = r"\b([12]\d{3}|\d{3})\b"       # 4 digit number beginning with a 1 or a 2, or, any 3 digit number

x1 = re.search(p3, text)
x2 = re.findall(p3, text)
print(x1)
print(x2)
# Out:
# <re.Match object; span=(102, 106), match='1945'>
# ['1945', '982']

# %% [markdown]
# ### Loading JSON file

# %%
import json
import os

# Change to the directory where the notebook is located
os.chdir(os.path.dirname(os.path.abspath("__file__")))
print("Current Directory:", os.getcwd())
PATH = "/minisubset/Emmy_Rossum/captions.json"
PATH = os.getcwd() + PATH

with open(PATH, "r") as f:
    data = json.load(f)

print(type(data))
for i in data:
    # this lists every json item
    print(i)
# Out:
# Current Directory: /home/maros/SEMESTER_2/PVT/wikiLLM
# <class 'list'>
# {'original_filename': 'Emma-Rossum 2011-03-08 photoby Adam-Bielawski.jpg', 'saved_filename': 'Emma-Rossum_2011-03-08_photoby_Adam-Bielawski.jpg', 'caption': 'Rossum in 2011', 'url': 'https://upload.wikimedia.org/wikipedia/commons/3/33/Emma-Rossum_2011-03-08_photoby_Adam-Bielawski.jpg'}
# {'original_filename': 'Homecoming 13 (44747938721) (cropped).jpg', 'saved_filename': 'Homecoming_13_(44747938721)_(cropped).jpg', 'caption': 'upright|Rossum and her husband Sam Esmail in September 2018', 'url': 'https://upload.wikimedia.org/wikipedia/commons/1/17/Homecoming_13_%2844747938721%29_%28cropped%29.jpg'}
